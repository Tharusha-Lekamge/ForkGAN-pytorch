# %%
import numpy as np
import tensorflow as tf
from scipy.linalg import sqrtm
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
import glob
import random


def calculate_fid_score(real_images_path, fake_images_path, num_images=500):
    # Load pre-trained InceptionV3 model
    inception_model = InceptionV3(
        include_top=False, pooling="avg", input_shape=(299, 299, 3)
    )

    # Feature extraction model
    feature_extractor = Model(
        inputs=inception_model.input, outputs=inception_model.layers[-1].output
    )

    def preprocess_images(image_paths):
        images = []
        for img_path in image_paths:
            img = image.load_img(img_path, target_size=(299, 299))
            img = image.img_to_array(img)
            img = np.expand_dims(img, axis=0)
            img = preprocess_input(img)
            images.append(img)
        return np.vstack(images)

    def calculate_activation_statistics(images):
        features = feature_extractor.predict(images)
        mu = np.mean(features, axis=0)
        sigma = np.cov(features, rowvar=False)
        return mu, sigma

    def calculate_frechet_distance(mu1, sigma1, mu2, sigma2):
        # Calculate the sum of squared differences between means
        ssdiff = np.sum((mu1 - mu2) ** 2.0)
        # Calculate the square root of the product between covariances
        covmean = sqrtm(sigma1.dot(sigma2))
        # Check for imaginary numbers and discard them
        if np.iscomplexobj(covmean):
            covmean = covmean.real
        # Calculate the Frechet distance
        fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
        return fid

    # Load and preprocess random subset of images
    real_image_paths = glob.glob(real_images_path)
    fake_image_paths = glob.glob(fake_images_path)
    real_images = preprocess_images(real_image_paths)
    fake_images = preprocess_images(fake_image_paths)

    # Calculate statistics for real and fake images
    mu1, sigma1 = calculate_activation_statistics(real_images)
    mu2, sigma2 = calculate_activation_statistics(fake_images)

    # Calculate FID score
    fid_score = calculate_frechet_distance(mu1, sigma1, mu2, sigma2)
    return fid_score


# Example usage:
real_images_path = "datasets/merged_ds/testB/*.jpg"
fake_images_path = "datasets/fid/fake/*.png"
fid_score = calculate_fid_score(real_images_path, fake_images_path)
print("FID Score:", fid_score)

# %%
import os

# Directory path
directory = "./results/bdd100k-rotated/test_latest/images"

# List all files in the directory
files = os.listdir(directory)

# Iterate over the files
for file in files:
    # Check if the file name starts with "frame"
    if file.startswith("frame"):
        # If it doesn't start with "frame", construct the full path and delete the file
        file_path = os.path.join(directory, file)
        os.remove(file_path)
        print(f"Deleted: {file_path}")

# %%
import os
import shutil


def move_files(source_dir, dest_dir):
    # Create destination directories if they don't exist
    os.makedirs(dest_dir, exist_ok=True)

    # List all files in the source directory
    files = os.listdir(source_dir)

    # Iterate over each file
    for file in files:
        # Check if the file ends with '_real_A.png' or '_fake_B.png'
        if file.endswith("_real_A.png"):
            # Move the file to the 'real' folder
            shutil.move(os.path.join(source_dir, file), os.path.join(dest_dir, "real"))
        elif file.endswith("_fake_B.png"):
            # Move the file to the 'fake' folder
            print("fake move")
            shutil.move(os.path.join(source_dir, file), os.path.join(dest_dir, "fake"))

# %%
# Specify source directory containing the files
source_directory = "results/results/bdd100k-complete/test_latest/images"

# Specify destination directory
destination_directory = "results/bdd100k-complete/fid"

# Call the function to move files
move_files(source_directory, destination_directory)

# %%
# Specify source directory containing the files
source_directory = "/path/to/source_directory"

# Specify destination directory
destination_directory = "/path/to/destination_directory"

# Call the function to move files
move_files(source_directory, destination_directory)

# %%
import os

directory = "./checkpoints/bdd100k-rotated-copy"

# List all files in the directory
files = os.listdir(directory)

# Iterate over the files
for file in files:
    if file.startswith("latest_"):
        # If the file starts with "latest_", delete it
        file_path = os.path.join(directory, file)
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    elif file.startswith("10_"):
        # If the file starts with "5_", rename it to start with "latest_"
        old_file_path = os.path.join(directory, file)
        new_file_name = file.replace("10_", "latest_")
        new_file_path = os.path.join(directory, new_file_name)
        os.rename(old_file_path, new_file_path)
        print(f"Renamed: {old_file_path} to {new_file_path}")
# Out:
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_net_D_rec_fake_B.pth to ./checkpoints/bdd100k-rotated-copy/latest_net_D_rec_fake_B.pth
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_net_DC.pth to ./checkpoints/bdd100k-rotated-copy/latest_net_DC.pth
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_net_D_rec_B.pth to ./checkpoints/bdd100k-rotated-copy/latest_net_D_rec_B.pth
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_optimizer_G.pth to ./checkpoints/bdd100k-rotated-copy/latest_optimizer_G.pth
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_scaler.pth to ./checkpoints/bdd100k-rotated-copy/latest_scaler.pth
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_net_D_rec_fake_A.pth to ./checkpoints/bdd100k-rotated-copy/latest_net_D_rec_fake_A.pth
# Renamed: ./checkpoints/bdd100k-rotated-copy/10_optimizer_DC.pth to ./checkpoints/bdd100k-rotated-copy/latest_optimizer_DC.pth
# ...

# %%
# RENAME

import os


def rename_files_with_prefix(directory, prefix="1-"):
    # Get list of files in the directory
    files = os.listdir(directory)

    # Iterate over each file in the directory
    for filename in files:
        # Construct the new filename with "1-" prefix
        new_filename = prefix + filename

        # Construct the full paths for old and new filenames
        old_path = os.path.join(directory, filename)
        new_path = os.path.join(directory, new_filename)

        # Rename the file
        os.rename(old_path, new_path)

    print("All files renamed successfully.")


# Example usage:
# directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-1-light"
# rename_files_with_prefix(directory_path, "1-light-")
# directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-2-dark"
# rename_files_with_prefix(directory_path, "2-dark-")
# directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-2-light"
# rename_files_with_prefix(directory_path, "2-light-")
directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-3-dark"
rename_files_with_prefix(directory_path, "3-dark-")
directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-3-light"
rename_files_with_prefix(directory_path, "3-light-")
directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-4-dark"
rename_files_with_prefix(directory_path, "4-dark-")
directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-4-light"
rename_files_with_prefix(directory_path, "4-light-")
directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-5-dark"
rename_files_with_prefix(directory_path, "5-dark-")
directory_path = "./datasets/scans/A-hostel-scans-extracted/hostel-5-light"
rename_files_with_prefix(directory_path, "5-light-")
# Out:
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.
# All files renamed successfully.

# %%
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-1-light/* ./datasets/hostel-ds/trainB
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-3-light/* ./datasets/hostel-ds/trainB
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-4-light/* ./datasets/hostel-ds/trainB
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-5-light/* ./datasets/hostel-ds/trainB

# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-1-dark/* ./datasets/hostel-ds/trainA
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-3-dark/* ./datasets/hostel-ds/trainA
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-4-dark/* ./datasets/hostel-ds/trainA
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-5-dark/* ./datasets/hostel-ds/trainA

# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-2-dark/* ./datasets/hostel-ds/testA
# !cp -r ./datasets/scans/A-hostel-scans-extracted/hostel-2-dark/* ./datasets/hostel-ds/testB
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
